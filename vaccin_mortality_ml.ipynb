# %%
# source:
# https://ourworldindata.org/vaccination
# https://ourworldindata.org/grapher/child-mortality-vs-share-of-children-immunized-against-diphtheria-pertussis-and-tetanus

# %%
import statsmodels.formula.api as smf
import pandas as pd
import numpy as np


df = pd.read_csv('child-mortality-vs-share-of-children-immunized-against-diphtheria-pertussis-and-tetanus.csv')
df
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1962
# 2        Afghanistan       AFG  1963
# 3        Afghanistan       AFG  1964
# 4        Afghanistan       AFG  1965
# ...              ...       ...   ...
# 57513       Zimbabwe       ZWE  1958
# 57514       Zimbabwe       ZWE  1959
# 57515       Zimbabwe       ZWE  2020
# 57516       Zimbabwe       ZWE  2021
# 57517  Åland Islands       ALA  2015
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                  NaN
# 1                                                34.46
# 2                                                33.87
# 3                                                33.31
# 4                                                32.76
# ...                                                ...
# 57513                                              NaN
# 57514                                              NaN
# 57515                                              NaN
# 57516                                              NaN
# 57517                                              NaN
#
#        DTP3 (% of one-year-olds immunized)  Population (historical estimates)  \
# 0                                      NaN                                NaN
# 1                                      NaN                          9351442.0
# 2                                      NaN                          9543200.0
# 3                                      NaN                          9744772.0
# 4                                      NaN                          9956318.0
# ...                                    ...                                ...
# 57513                                  NaN                          3537167.0
# 57514                                  NaN                          3654172.0
# 57515                                  NaN                         14862927.0
# 57516                                  NaN                         15092171.0
# 57517                                  NaN                                NaN
#
#       Continent
# 0          Asia
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 57513       NaN
# 57514       NaN
# 57515       NaN
# 57516       NaN
# 57517    Europe
#
# [57518 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Entity                                                 0
# Code                                                3439
# Year                                                   0
# Mortality rate, under-5 (per 1,000 live births)    45573
# DTP3 (% of one-year-olds immunized)                49855
# Population (historical estimates)                   1862
# Continent                                          57233
# dtype: int64

# %%
# extract data from 1980 onwards
df=df[df['Year']>=1980]
df
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 19       Afghanistan       AFG  1980
# 20       Afghanistan       AFG  1981
# 21       Afghanistan       AFG  1982
# 22       Afghanistan       AFG  1983
# ...              ...       ...   ...
# 57316       Zimbabwe       ZWE  2018
# 57317       Zimbabwe       ZWE  2019
# 57515       Zimbabwe       ZWE  2020
# 57516       Zimbabwe       ZWE  2021
# 57517  Åland Islands       ALA  2015
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                  NaN
# 19                                               24.15
# 20                                               23.51
# 21                                               22.86
# 22                                               22.22
# ...                                                ...
# 57316                                             5.59
# 57317                                             5.46
# 57515                                              NaN
# 57516                                              NaN
# 57517                                              NaN
#
#        DTP3 (% of one-year-olds immunized)  Population (historical estimates)  \
# 0                                      NaN                                NaN
# 19                                     4.0                         13356500.0
# 20                                     3.0                         13171679.0
# 21                                     5.0                         12882518.0
# 22                                     5.0                         12537732.0
# ...                                    ...                                ...
# 57316                                 89.0                         14438812.0
# 57317                                 90.0                         14645473.0
# 57515                                  NaN                         14862927.0
# 57516                                  NaN                         15092171.0
# 57517                                  NaN                                NaN
#
#       Continent
# 0          Asia
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# ...         ...
# 57316       NaN
# 57317       NaN
# 57515       NaN
# 57516       NaN
# 57517    Europe
#
# [12036 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Entity                                                 0
# Code                                                2077
# Year                                                   0
# Mortality rate, under-5 (per 1,000 live births)     2923
# DTP3 (% of one-year-olds immunized)                 4373
# Population (historical estimates)                   1832
# Continent                                          11751
# dtype: int64

# %%
# When Code is Null, it represents continent or a specific region
df[df['Code'].isnull()]
# Out:
#                 Entity Code  Year  \
# 260             Africa  NaN  1980
# 261             Africa  NaN  1981
# 262             Africa  NaN  1982
# 263             Africa  NaN  1983
# 264             Africa  NaN  1984
# ...                ...  ...   ...
# 56358  Western Pacific  NaN  2015
# 56359  Western Pacific  NaN  2016
# 56360  Western Pacific  NaN  2017
# 56361  Western Pacific  NaN  2018
# 56362  Western Pacific  NaN  2019
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# ...                                                ...
# 56358                                              NaN
# 56359                                              NaN
# 56360                                              NaN
# 56361                                              NaN
# 56362                                              NaN
#
#        DTP3 (% of one-year-olds immunized)  Population (historical estimates)  \
# 260                                    5.0                        476386225.0
# 261                                   11.0                        490003904.0
# 262                                   12.0                        504034176.0
# 263                                   18.0                        518479759.0
# 264                                   24.0                        533345151.0
# ...                                    ...                                ...
# 56358                                 94.0                                NaN
# 56359                                 97.0                                NaN
# 56360                                 95.0                                NaN
# 56361                                 93.0                                NaN
# 56362                                 94.0                                NaN
#
#       Continent
# 260         NaN
# 261         NaN
# 262         NaN
# 263         NaN
# 264         NaN
# ...         ...
# 56358       NaN
# 56359       NaN
# 56360       NaN
# 56361       NaN
# 56362       NaN
#
# [2077 rows x 7 columns]

# %%
df=df[df['Code'].notnull()]
df=df[df['Mortality rate, under-5 (per 1,000 live births)'].notnull()]
df=df[df['DTP3 (% of one-year-olds immunized)'].notnull()]
df=df[df['Population (historical estimates)'].notnull()]
df
# Out:
#             Entity Code  Year  \
# 19     Afghanistan  AFG  1980
# 20     Afghanistan  AFG  1981
# 21     Afghanistan  AFG  1982
# 22     Afghanistan  AFG  1983
# 23     Afghanistan  AFG  1984
# ...            ...  ...   ...
# 57313     Zimbabwe  ZWE  2015
# 57314     Zimbabwe  ZWE  2016
# 57315     Zimbabwe  ZWE  2017
# 57316     Zimbabwe  ZWE  2018
# 57317     Zimbabwe  ZWE  2019
#
#        Mortality rate, under-5 (per 1,000 live births)  \
# 19                                               24.15
# 20                                               23.51
# 21                                               22.86
# 22                                               22.22
# 23                                               21.58
# ...                                                ...
# 57313                                             6.20
# 57314                                             5.95
# 57315                                             5.82
# 57316                                             5.59
# 57317                                             5.46
#
#        DTP3 (% of one-year-olds immunized)  Population (historical estimates)  \
# 19                                     4.0                         13356500.0
# 20                                     3.0                         13171679.0
# 21                                     5.0                         12882518.0
# 22                                     5.0                         12537732.0
# 23                                    16.0                         12204306.0
# ...                                    ...                                ...
# 57313                                 87.0                         13814642.0
# 57314                                 90.0                         14030338.0
# 57315                                 89.0                         14236599.0
# 57316                                 89.0                         14438812.0
# 57317                                 90.0                         14645473.0
#
#       Continent
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# ...         ...
# 57313    Africa
# 57314       NaN
# 57315       NaN
# 57316       NaN
# 57317       NaN
#
# [7006 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Entity                                                0
# Code                                                  0
# Year                                                  0
# Mortality rate, under-5 (per 1,000 live births)       0
# DTP3 (% of one-year-olds immunized)                   0
# Population (historical estimates)                     0
# Continent                                          6816
# dtype: int64

# %%
df.rename(columns={'Mortality rate, under-5 (per 1,000 live births)': 'mortality_rate', 'DTP3 (% of one-year-olds immunized)': 'immunized_per_cent'}, inplace=True)
df
# Out:
#             Entity Code  Year  mortality_rate  immunized_per_cent  \
# 19     Afghanistan  AFG  1980           24.15                 4.0
# 20     Afghanistan  AFG  1981           23.51                 3.0
# 21     Afghanistan  AFG  1982           22.86                 5.0
# 22     Afghanistan  AFG  1983           22.22                 5.0
# 23     Afghanistan  AFG  1984           21.58                16.0
# ...            ...  ...   ...             ...                 ...
# 57313     Zimbabwe  ZWE  2015            6.20                87.0
# 57314     Zimbabwe  ZWE  2016            5.95                90.0
# 57315     Zimbabwe  ZWE  2017            5.82                89.0
# 57316     Zimbabwe  ZWE  2018            5.59                89.0
# 57317     Zimbabwe  ZWE  2019            5.46                90.0
#
#        Population (historical estimates) Continent
# 19                            13356500.0       NaN
# 20                            13171679.0       NaN
# 21                            12882518.0       NaN
# 22                            12537732.0       NaN
# 23                            12204306.0       NaN
# ...                                  ...       ...
# 57313                         13814642.0    Africa
# 57314                         14030338.0       NaN
# 57315                         14236599.0       NaN
# 57316                         14438812.0       NaN
# 57317                         14645473.0       NaN
#
# [7006 rows x 7 columns]

# %%
model = smf.ols(formula = "mortality_rate ~ immunized_per_cent", data = df).fit()

print("Model trained!")
# Out:
# Model trained!

# %%
import joblib
model_filename = './vaccin_mortality_model.pkl'
joblib.dump(model, model_filename)
print("Model saved!")
# Out:
# Model saved!

# %%
model_loaded = joblib.load(model_filename)
print("We have loaded a model with the following parameters:")
print(model_loaded.params)
# Out:
# We have loaded a model with the following parameters:
# Intercept             20.029493
# immunized_per_cent    -0.184140
# dtype: float64

# %%
print(model_loaded.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         mortality_rate   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     8047.
# Date:                Sat, 02 Apr 2022   Prob (F-statistic):               0.00
# Time:                        16:25:39   Log-Likelihood:                -19383.
# No. Observations:                7006   AIC:                         3.877e+04
# Df Residuals:                    7004   BIC:                         3.878e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             20.0295      0.170    118.123      0.000      19.697      20.362
# immunized_per_cent    -0.1841      0.002    -89.703      0.000      -0.188      -0.180
# ==============================================================================
# Omnibus:                     1357.965   Durbin-Watson:                   0.174
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4452.603
# Skew:                           0.975   Prob(JB):                         0.00
# Kurtosis:                       6.383   Cond. No.                         305.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Let's write a function that loads and uses our model
def load_model_and_predict(vaccine):

    # Load the model from file and print basic information about it
    loaded_model = joblib.load(model_filename)
    print("We have loaded a model with the following parameters:")
    print(loaded_model.params)
    # Prepare data for the model
    inputs = {"immunized_per_cent":[vaccine]} 
    # Use the model to make a prediction
    predicted_mortality_rate = loaded_model.predict(inputs)[0]
    return predicted_mortality_rate
# Practice using our model
predicted_mortality_rate = load_model_and_predict(90)
print("Mortality rate, under-5 (per 1,000 live births):", predicted_mortality_rate)
# Out:
# We have loaded a model with the following parameters:
# Intercept             20.029493
# immunized_per_cent    -0.184140
# dtype: float64
# Mortality rate, under-5 (per 1,000 live births): 3.456906879972326
